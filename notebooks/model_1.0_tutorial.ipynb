# %%
from utils import normalize_df, create_train_test_val_df
import os
notebook_dir = os.getcwd()
root_dir = os.path.abspath(os.path.join(notebook_dir, '..'))
data_dir = os.path.join(root_dir, 'data')
import numpy as np
import pandas as pd
from IPython.display import display_html
from copy import deepcopy
import pickle
# from utils.utils

# %% [markdown]
# # Model 1.0
# This notebook will act as an interactive tutorial for our Live Win Probability Model. This "model" is actual comprised of 3 separate models that "stack" on each other.
# 1. Play and drive outcome models
#     * technically this is two separate models:
#         * Play outcome (first down, field goal made, field goal missed, touchdown, turnover, and none/other)
#             * only using the first down prediction from the output of this model
#         * Drive outcome (Clock, field goal made, field goal missed, punt, safety, touch down, turnover, turnover on downs)
#     * outputs for both models will be a series of probabilities for each class that all add up to 1
# 2. End of regulation score differential model
#     * Dealing with overtime later, we want to predict how the score differential will change by the end of regulation.
#         * i.e., if the current score differential (home score - away score) is -3 and the end of regulation score differential is -10, the target value will be -7
#     * Output of this will be a series of probabilities from for all score differential possibilities from -35 to 35 (outputs <-35 or >35 will be set to -35/35 respectively)
# 3. End of regulation score total model
#     * Similar concept to the score differential model
#     * Again, we're using the change in end of regulation score total as the target value
#     * Outputs will be a series of probabilites for classes from 0 to 83 (outputs will be capped at 83)

# %% [markdown]
# ## Data
# Let's take a look at the data that we are pulling from oracle
# * First we have event_df and odds_df
# * event_df is the play by play data mixed with some import game information
# * Odds data has vegas predictions for almost all the games in the set (missing games will be given the average vegas spread and over/under)
#     * The spread and over/under are merged with the event table to give us our pre-game priors
#     * some games have multiple odds so duplicates are removed

# %%
event_df = pd.read_parquet(os.path.join(data_dir, "event_data.parquet"))
event_df = event_df.drop_duplicates(["nevent", "game_code"]).reset_index(drop=True)
odds_df = pd.read_parquet(os.path.join(data_dir, "odds_data.parquet"))
odds_df = odds_df.drop_duplicates("game_code")
event_df[["cur_spread", "cur_over_under"]] = event_df.merge(odds_df, how="left", on="game_code")[["cur_spread", "cur_over_under"]].fillna({"cur_spread": np.mean(odds_df["cur_spread"]), "cur_over_under": np.mean(odds_df["cur_over_under"])})
pd.set_option("display.max_columns", None)
display_html(event_df)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>game_code</th>
#       <th>game_date</th>
#       <th>season</th>
#       <th>home_team_id</th>
#       <th>home_team</th>
#       <th>home_team_abbrev</th>
#       <th>away_team_id</th>
#       <th>away_team</th>
#       <th>away_team_abbrev</th>
#       <th>home_final_score</th>
#       <th>away_final_score</th>
#       <th>final_score_diff</th>
#       <th>end_of_regulation_score_diff</th>
#       <th>home_rest_of_game_score</th>
#       <th>away_rest_of_game_score</th>
#       <th>end_of_regulation_score_diff_change</th>
#       <th>home_score_added</th>
#       <th>away_score_added</th>
#       <th>current_score_diff</th>
#       <th>current_score_total</th>
#       <th>home_start_score</th>
#       <th>away_start_score</th>
#       <th>home_team_outcome</th>
#       <th>home_team_win</th>
#       <th>draw</th>
#       <th>away_team_win</th>
#       <th>nevent</th>
#       <th>quarter</th>
#       <th>overtime</th>
#       <th>home_team_has_ball</th>
#       <th>off_team_id</th>
#       <th>def_team_id</th>
#       <th>kick_off</th>
#       <th>punt</th>
#       <th>point_after_kick</th>
#       <th>two_point_attempt</th>
#       <th>field_goal_attempt</th>
#       <th>off_start_score</th>
#       <th>off_end_score</th>
#       <th>off_score_change</th>
#       <th>def_start_score</th>
#       <th>def_end_score</th>
#       <th>def_score_change</th>
#       <th>play_counts</th>
#       <th>efficiency_counts</th>
#       <th>from_scrimmage</th>
#       <th>first_down</th>
#       <th>scoring_play</th>
#       <th>possession_change</th>
#       <th>continuation</th>
#       <th>event_name</th>
#       <th>event_id</th>
#       <th>yards_gained</th>
#       <th>drive_outcome_id</th>
#       <th>drive_outcome_desc</th>
#       <th>down</th>
#       <th>ytg</th>
#       <th>yd_from_goal</th>
#       <th>drive_id</th>
#       <th>drive_start</th>
#       <th>play_start_time</th>
#       <th>cur_spread</th>
#       <th>cur_over_under</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>819846</td>
#       <td>2008-09-04</td>
#       <td>2008</td>
#       <td>351</td>
#       <td>New York Giants</td>
#       <td>NYG</td>
#       <td>363</td>
#       <td>Washington Redskins</td>
#       <td>Was</td>
#       <td>16</td>
#       <td>7</td>
#       <td>9</td>
#       <td>9</td>
#       <td>16</td>
#       <td>7</td>
#       <td>9</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>W</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>363</td>
#       <td>351</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>Kick Off</td>
#       <td>5</td>
#       <td>73.0</td>
#       <td>NaN</td>
#       <td>None</td>
#       <td>0</td>
#       <td>-1</td>
#       <td>70</td>
#       <td>NaN</td>
#       <td>3600</td>
#       <td>900.0</td>
#       <td>-4.5</td>
#       <td>41.5</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>819846</td>
#       <td>2008-09-04</td>
#       <td>2008</td>
#       <td>351</td>
#       <td>New York Giants</td>
#       <td>NYG</td>
#       <td>363</td>
#       <td>Washington Redskins</td>
#       <td>Was</td>
#       <td>16</td>
#       <td>7</td>
#       <td>9</td>
#       <td>9</td>
#       <td>16</td>
#       <td>7</td>
#       <td>9</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>W</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>2</td>
#       <td>1</td>
#       <td>0</td>
#       <td>1</td>
#       <td>351</td>
#       <td>363</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>Kick Off Return</td>
#       <td>6</td>
#       <td>19.0</td>
#       <td>NaN</td>
#       <td>None</td>
#       <td>0</td>
#       <td>-1</td>
#       <td>103</td>
#       <td>NaN</td>
#       <td>3600</td>
#       <td>900.0</td>
#       <td>-4.5</td>
#       <td>41.5</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>819846</td>
#       <td>2008-09-04</td>
#       <td>2008</td>
#       <td>351</td>
#       <td>New York Giants</td>
#       <td>NYG</td>
#       <td>363</td>
#       <td>Washington Redskins</td>
#       <td>Was</td>
#       <td>16</td>
#       <td>7</td>
#       <td>9</td>
#       <td>9</td>
#       <td>16</td>
#       <td>7</td>
#       <td>9</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>W</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>3</td>
#       <td>1</td>
#       <td>0</td>
#       <td>1</td>
#       <td>351</td>
#       <td>363</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>Run</td>
#       <td>4</td>
#       <td>3.0</td>
#       <td>37.0</td>
#       <td>TD</td>
#       <td>1</td>
#       <td>10</td>
#       <td>84</td>
#       <td>1.0</td>
#       <td>3600</td>
#       <td>895.0</td>
#       <td>-4.5</td>
#       <td>41.5</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>819846</td>
#       <td>2008-09-04</td>
#       <td>2008</td>
#       <td>351</td>
#       <td>New York Giants</td>
#       <td>NYG</td>
#       <td>363</td>
#       <td>Washington Redskins</td>
#       <td>Was</td>
#       <td>16</td>
#       <td>7</td>
#       <td>9</td>
#       <td>9</td>
#       <td>16</td>
#       <td>7</td>
#       <td>9</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>W</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>4</td>
#       <td>1</td>
#       <td>0</td>
#       <td>1</td>
#       <td>351</td>
#       <td>363</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>Incomplete Pass</td>
#       <td>2</td>
#       <td>0.0</td>
#       <td>37.0</td>
#       <td>TD</td>
#       <td>2</td>
#       <td>7</td>
#       <td>81</td>
#       <td>1.0</td>
#       <td>3600</td>
#       <td>860.0</td>
#       <td>-4.5</td>
#       <td>41.5</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>819846</td>
#       <td>2008-09-04</td>
#       <td>2008</td>
#       <td>351</td>
#       <td>New York Giants</td>
#       <td>NYG</td>
#       <td>363</td>
#       <td>Washington Redskins</td>
#       <td>Was</td>
#       <td>16</td>
#       <td>7</td>
#       <td>9</td>
#       <td>9</td>
#       <td>16</td>
#       <td>7</td>
#       <td>9</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>W</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>5</td>
#       <td>1</td>
#       <td>0</td>
#       <td>1</td>
#       <td>351</td>
#       <td>363</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>Pass Completion<

# %% [markdown]
# Adding timeouts remaining for both teams and time left in game

# %%
event_df["half"] = round((event_df["quarter"] + 0.01) / 2)
event_df["home_timeout"] = np.where(((event_df["event_id"]==57)&(event_df["home_team_has_ball"]==1))|((event_df["event_id"]==58)&(event_df["home_team_has_ball"]==0)), 1, 0)
event_df["away_timeout"] = np.where(((event_df["event_id"]==57)&(event_df["home_team_has_ball"]==0))|((event_df["event_id"]==58)&(event_df["home_team_has_ball"]==1)), 1, 0)
event_df["home_timeouts_remaining"] = np.clip(3 - event_df.groupby(["game_code", "half"])["home_timeout"].cumsum(), 0, 3)
event_df["away_timeouts_remaining"] = np.clip(3 - event_df.groupby(["game_code", "half"])["away_timeout"].cumsum(), 0, 3)
event_df["time_left_in_game"] = np.where(event_df["quarter"] <= 4, event_df["play_start_time"] + (4 - event_df["quarter"]) * 900, event_df["play_start_time"])
# event_df["time_elapsed"] = 900 - event_df["play_start_time"] + (event_df["quarter"] - 1) * 900

# %% [markdown]
# * Our PBP will have multiple rows for one play, so if there's a fumble then recovery by offense and a touchdown,
# * that could have 2-3 rows of data and the touchdown wouldn't show up as being apart of the original play
#     * plays would look like this: 1. Run, 2. Fumble, 3. Offense Recovers the ball (TD)
# * So what we've done here is ensure that plays that are "continuation" that end in a touchdown, give a TD=True for all of the plays in the sequence
# * After that is taken care of we can setup all of the labels for play and drive description

# %%
event_df["sequence"] = event_df["continuation"].groupby(event_df["continuation"].eq(0).cumsum()).cumsum()
event_df["play_start_id"] = event_df["nevent"] - event_df["sequence"]

turnover_ids = [9, 16]
event_df["turnover"] = np.where(event_df["event_id"].isin(turnover_ids), 1, 0)
event_df["touchdown_scored"] = np.where(event_df["home_score_added"]+event_df["away_score_added"]>=6, 1, 0)
event_df["fieldgoal_made"] = np.where(event_df["home_score_added"]+event_df["away_score_added"]==3, 1, 0)

play_outcome_aggregate =event_df[["game_code", "play_start_id", "turnover", "touchdown_scored", "fieldgoal_made", "first_down"]].groupby(["game_code", "play_start_id"], as_index=False).sum()
event_df["touchdown_in_play"] = np.clip(event_df.merge(play_outcome_aggregate,on=["game_code", "play_start_id"], how="left")["touchdown_scored_y"], 0, 1)
event_df["turnover_in_play"] = np.clip(event_df.merge(play_outcome_aggregate,on=["game_code", "play_start_id"], how="left")["turnover_y"], 0, 1)
event_df["field_goal_in_play"] = np.clip(event_df.merge(play_outcome_aggregate,on=["game_code", "play_start_id"], how="left")["fieldgoal_made_y"], 0, 1)
event_df["first_down_in_play"] = np.clip(event_df.merge(play_outcome_aggregate,on=["game_code", "play_start_id"], how="left")["first_down_y"], 0, 1)



event_df["play_outcome"] = (
    np.where((event_df["turnover_in_play"]==1), "turnover",
    # (event_df["touchdown_in_play"]==1)&(event_df["turnover_in_play"]==1), "defensive_touchdown", 
    np.where((event_df["field_goal_in_play"]==1), "field_goal_made",
    np.where((event_df["field_goal_attempt"]==1)&(event_df["field_goal_in_play"]==0), "field_goal_missed",
    np.where((event_df["first_down_in_play"]==1)&(event_df["touchdown_in_play"]==0)&(event_df["turnover_in_play"]==0), "first_down",
    np.where((event_df["touchdown_in_play"]==1)&(event_df["turnover_in_play"]==0), "offensive_touchdown", "none")))))
)
drive_description_matrix = {
    7: "punt",
    9: "turnover",
    14: "turnover",
    17: "field_goal_made",
    18: "punt",
    20: "safety",
    35: "field_goal_missed",
    36: "field_goal_missed",
    37: "touch_down",
    38: "clock",
    39: "clock",
    40: "turnover_on_downs",
    42: "field_goal_made",
    51: "clock",
}
event_df["drive_outcome_desc_basic"] = event_df["drive_outcome_id"].map(drive_description_matrix)

# event_df["drive_outcome"] = np.where(
#     (event_df["touchdown_in_drive"]==1)&(event_df["turnover_in_drive"]==1), "defensive_touchdown", 
#     np.where((event_df["touchdown_in_drive"]==1)&(event_df["turnover_in_drive"]==0), "offensive_touchdown",
#     np.where((event_df["field_goal_in_drive"]==1), "field_goal_made",
#     np.where((event_df["touchdown_in_drive"]==0)&(event_df["turnover_in_drive"]==1), "turnover", "none"
# ))))
game_end_of_regulation_total_score = event_df[event_df.overtime==0].groupby("game_code", as_index=False).max()[["game_code", "home_start_score", "away_start_score"]]
game_end_of_regulation_total_score["end_of_regulation_score_total"] = game_end_of_regulation_total_score["home_start_score"] + game_end_of_regulation_total_score["away_start_score"]
# event_df["end_of_regulation_score_total_diff"] = 
event_df["end_of_regulation_score_total_diff"] = (
    event_df.merge(game_end_of_regulation_total_score, on="game_code")["end_of_regulation_score_total"]
    - (event_df["home_start_score"] + event_df["away_start_score"])
)
# Out:
# /var/folders/dq/tcxv3s4j7y585_4jhfbdvrx00000gn/T/ipykernel_3313/4279417664.py:50: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   game_end_of_regulation_total_score = event_df[event_df.overtime==0].groupby("game_code", as_index=False).max()[["game_code", "home_start_score", "away_start_score"]]

# %% [markdown]
# ### Data Manipulation
# * We need to do a little bit of data manipulation to get the values we need, but we don't want to "overwrite" the values in event_df so we'll make copy of it called model_df
# * time left in half is added
# * from_scrimmage is changed so that PATs and two point conversions are not included
# * down, ytg, and yd_from_goal are changed so that all non-scrimmage plays are changed to a default "null" value
# * home_team_has_ball is change so that when kickoffs occur, the team receiving is the one that is in possession of the ball
#
# ### Data Subset
# * Removing continuation plays that we mentioned before, so that each snap has just one target
# * Remove plays where the down is equal to 0
# * Remove plays from scrimmage that did not count (e.g., plays that were waved off by penalties)
# * scrimmage_plays_we_want is event_id of all the scrimmage plays that *aren't* timeouts, end of quarters, and the two minute warning.
# * Remove all NA values for the feature inputs and target
# * Remove all plays that are not from scrimmage
# * Remove all overtime plays

# %%
model_df = deepcopy(event_df)
model_df["time_left_in_half"] = event_df["time_left_in_game"] - ((2 - event_df["half"]) * 1800)
model_df["from_scrimmage"] = np.where(event_df["event_id"].isin([22, 47, 52, 53, 54, 55, 56]), 0, event_df["from_scrimmage"])
model_df["down"] = np.where(model_df["from_scrimmage"] == 0, 0, event_df["down"])
model_df["ytg"] = np.where(model_df["from_scrimmage"] == 0, -1, event_df["ytg"])
model_df["yd_from_goal"] = np.where(model_df["from_scrimmage"] == 0, -1, event_df["yd_from_goal"])
model_df["home_team_has_ball"] = np.where(event_df["event_id"].isin([5]), 1 - event_df["home_team_has_ball"], event_df["home_team_has_ball"])
scrimmage_plays_we_want = [1, 2, 3, 4, 7, 9, 14, 17, 18, 35]

input_names = [
    'time_left_in_half',
    'half',
    'current_score_diff',
    'current_score_total',
    'cur_spread',
    'cur_over_under',
    'home_timeouts_remaining',
    'away_timeouts_remaining',
    'punt',
    'field_goal_attempt',
    'ytg',
    'yd_from_goal',
    'down',
    'home_team_has_ball',
]
mask_model = (
    (model_df.continuation==0)&
    (model_df.down!=0)&
    (model_df.play_counts==1)&
    (model_df.event_id.isin(scrimmage_plays_we_want))&
    (model_df[input_names].notna().all(axis=1))&
    (model_df["from_scrimmage"]==1)&
    (model_df["overtime"]==0)
)

# %% [markdown]
# Let's take a look at what the input features and output features look like.
#
# Event Name and yards gained is included to help interpret what is going on.
#
# This is the first 2 drives of the first game in the dataset

# %%
model_df[mask_model][input_names + ["event_name", "yards_gained", "play_outcome", "drive_outcome_desc_basic"]].head(15)
# Out:
#     time_left_in_half  half  current_score_diff  current_score_total  \
# 2              1795.0   1.0                   0                    0
# 3              1760.0   1.0                   0                    0
# 4              1754.0   1.0                   0                    0
# 5              1723.0   1.0                   0                    0
# 6              1676.0   1.0                   0                    0
# 7              1650.0   1.0                   0                    0
# 8              1612.0   1.0                   0                    0
# 9              1562.0   1.0                   0                    0
# 10             1555.0   1.0                   0                    0
# 11             1517.0   1.0                   0                    0
# 14             1501.0   1.0                   0                    0
# 18             1488.0   1.0                   7                    7
# 19             1460.0   1.0                   7                    7
# 21             1402.0   1.0                   7                    7
# 22             1365.0   1.0                   7                    7
#
#     cur_spread  cur_over_under  home_timeouts_remaining  \
# 2         -4.5            41.5                        3
# 3         -4.5            41.5                        3
# 4         -4.5            41.5                        3
# 5         -4.5            41.5                        3
# 6         -4.5            41.5                        3
# 7         -4.5            41.5                        3
# 8         -4.5            41.5                        3
# 9         -4.5            41.5                        3
# 10        -4.5            41.5                        3
# 11        -4.5            41.5                        3
# 14        -4.5            41.5                        3
# 18        -4.5            41.5                        3
# 19        -4.5            41.5                        3
# 21        -4.5            41.5                        3
# 22        -4.5            41.5                        3
#
#     away_timeouts_remaining  punt  field_goal_attempt  ytg  yd_from_goal  \
# 2                         3     0                   0   10            84
# 3                         3     0                   0    7            81
# 4                         3     0                   0    7            81
# 5                         3     0                   0   10            73
# 6                         3     0                   0    7            70
# 7                         3     0                   0   10            40
# 8                         3     0                   0   10            21
# 9                         3     0                   0    6            17
# 10                        3     0                   0    6            17
# 11                        3     0                   0    6             6
# 14                        3     0                   0    1             1
# 18                        3     0                   0   10            73
# 19                        3     0                   0   18            81
# 21                        3     0                   0   20            83
# 22                        3     1                   0   15            78
#
#     down  home_team_has_ball       event_name  yards_gained  \
# 2      1                   1              Run           3.0
# 3      2                   1  Incomplete Pass           0.0
# 4      3                   1  Pass Completion           8.0
# 5      1                   1              Run           3.0
# 6      2                   1  Pass Completion          30.0
# 7      1                   1  Pass Completion          19.0
# 8      1                   1              Run           4.0
# 9      2                   1  Incomplete Pass           0.0
# 10     3                   1  Pass Completion          11.0
# 11     1                   1  Incomplete Pass           0.0
# 14     1                   1              Run           1.0
# 18     1                   0             Sack          -8.0
# 19     2                   0              Run           3.0
# 21     3                   0              Run           5.0
# 22     4                   0             Punt          34.0
#
#            play_outcome drive_outcome_desc_basic
# 2                  none               touch_down
# 3                  none               touch_down
# 4            first_down               touch_down
# 5                  none               touch_down
# 6            first_down               touch_down
# 7            first_down               touch_down
# 8                  none               touch_down
# 9                  none               touch_down
# 10           first_down               touch_down
# 11                 none               touch_down
# 14  offensive_touchdown               touch_down
# 18                 none                     punt
# 19                 none                     punt
# 21                 none                     punt
# 22                 none                     punt

# %% [markdown]
# ### Loading in the Models and Creating Play/Drive Predictions
# * For this exercise we won't be training the models, just loading saved models and then using them to make predictions
# * We're now including plays that didn't wind up counting
# * In addition, each prediction will be split up between home and away. So if the home team has the ball the predictions for the away team play/drive outcomes are going to be set to 0
#
#
# Let's take a look at how the home team predictions look for our dataset

# %%
search_rf_play_outcome = pickle.load(open(os.path.join(root_dir, "models/search_rf_play_outcome.p"), 'rb'))
search_rf_drive_outcome = pickle.load(open(os.path.join(root_dir, "models/search_rf_drive_outcome.p"), 'rb'))
search_rf_play_outcome.best_estimator_.verbose = 0
search_rf_drive_outcome.best_estimator_.verbose = 0


mask_model_predict = (
    (model_df.continuation==0)&
    (model_df.down!=0)&
    (model_df[input_names].notna().all(axis=1))&
    (model_df["from_scrimmage"]==1)&
    (model_df["overtime"]==0)
)


search_rf_play_class_names = ["search_rf_play_" + x for x in search_rf_play_outcome.classes_]
search_rf_drive_class_names = ["search_rf_drive_" + x for x in search_rf_drive_outcome.classes_]
model_df[search_rf_play_class_names] = pd.DataFrame(search_rf_play_outcome.predict_proba(model_df[mask_model_predict][input_names]), index=model_df[mask_model_predict].index)
model_df[search_rf_play_class_names] = model_df[search_rf_play_class_names]
model_df[search_rf_drive_class_names] = pd.DataFrame(search_rf_drive_outcome.predict_proba(model_df[mask_model_predict][input_names]), index=model_df[mask_model_predict].index)
model_df[search_rf_drive_class_names] = model_df[search_rf_drive_class_names]

search_rf_play_class_names_home = [x + "_home" for x in search_rf_play_class_names]
search_rf_play_class_names_away = [x + "_away" for x in search_rf_play_class_names]
search_rf_drive_class_names_home = [x + "_home" for x in search_rf_drive_class_names]
search_rf_drive_class_names_away = [x + "_away" for x in search_rf_drive_class_names]
model_df[search_rf_play_class_names_home] = model_df[search_rf_play_class_names].where(model_df.home_team_has_ball==1, 0)
model_df[search_rf_play_class_names_away] = model_df[search_rf_play_class_names].where(model_df.home_team_has_ball==0, 0)
model_df[search_rf_drive_class_names_home] = model_df[search_rf_drive_class_names].where(model_df.home_team_has_ball==1, 0)
model_df[search_rf_drive_class_names_away] = model_df[search_rf_drive_class_names].where(model_df.home_team_has_ball==0, 0)
display_html(model_df[mask_model][search_rf_play_class_names_home].head(15))
display_html(model_df[mask_model][search_rf_drive_class_names_home].head(15))
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>search_rf_play_field_goal_made_home</th>
#       <th>search_rf_play_field_goal_missed_home</th>
#       <th>search_rf_play_first_down_home</th>
#       <th>search_rf_play_none_home</th>
#       <th>search_rf_play_offensive_touchdown_home</th>
#       <th>search_rf_play_turnover_home</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2</th>
#       <td>0.000000e+00</td>
#       <td>0.000000</td>
#       <td>0.177257</td>
#       <td>0.797776</td>
#       <td>0.006842</td>
#       <td>0.018125</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2.762011e-07</td>
#       <td>0.000005</td>
#       <td>0.269195</td>
#       <td>0.703363</td>
#       <td>0.006831</td>
#       <td>0.020607</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0.000000e+00</td>
#       <td>0.000003</td>
#       <td>0.344761</td>
#       <td>0.608076</td>
#       <td>0.009020</td>
#       <td>0.038140</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>1.224140e-06</td>
#       <td>0.000000</td>
#       <td>0.184944</td>
#       <td>0.789976</td>
#       <td>0.009224</td>
#       <td>0.015855</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>2.762011e-07</td>
#       <td>0.000006</td>
#       <td>0.298935</td>
#       <td>0.670069</td>
#       <td>0.009723</td>
#       <td>0.021267</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>1.224140e-06</td>
#       <td>0.000000</td>
#       <td>0.189624</td>
#       <td>0.782763</td>
#       <td>0.011211</td>
#       <td>0.016400</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>1.094359e-05</td>
#       <td>0.000000</td>
#       <td>0.104436</td>
#       <td>0.819032</td>
#       <td>0.062322</td>
#       <td>0.014200</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>3.027111e-04</td>
#       <td>0.000062</td>
#       <td>0.274966</td>
#       <td>0.643217</td>
#       <td>0.059572</td>
#       <td>0.021879</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>2.973331e-04</td>
#       <td>0.000062</td>
#       <td>0.309201</td>
#       <td>0.588757</td>
#       <td>0.068857</td>
#       <td>0.032825</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>2.617972e-07</td>
#       <td>0.000000</td>
#       <td>0.018438</td>
#       <td>0.777139</td>
#       <td>0.194211</td>
#       <td>0.010212</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>8.376672e-05</td>
#       <td>0.000000</td>
#       <td>0.010879</td>
#       <td>0.438153</td>
#       <td>0.538790</td>
#       <td>0.012094</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>0.000000e+00</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>0.000000e+00</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>0.000000e+00</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>0.000000e+00</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#   </tbody>
# </table>
# </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>search_rf_drive_clock_home</th>
#       <th>search_rf_drive_field_goal_made_home</th>
#       <th>search_rf_drive_field_goal_missed_home</th>
#       <th>search_rf_drive_punt_home</th>
#       <th>search_rf_drive_safety_home</th>
#       <th>search_rf_drive_touch_down_home</th>
#       <th>search_rf_drive_turnover_home</th>
#       <th>search_rf_drive_turnover_on_downs_home</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2</th>
#       <td>0.001627</td>
#       <td>0.116460</td>
#       <td>0.022646</td>
#       <td>0.543364</td>
#       <td>0.003435</td>
#       <td>0.175361</td>
#       <td>0.120722</td>
#       <td>0.016386</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0.001256</td>
#       <td>0.110399</td>
#       <td>0.020726</td>
#       <td>0.578062</td>
#       <td>0.002997</td>
#       <td>0.159085</td>
#       <td>0.111848</td>
#       <td>0.015627</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0.000609</td>
#       <td>0.071220</td>
#       <td>0.012759</td>
#       <td>0.711120</td>
#       <td>0.003036</td>
#       <td>0.101360</td>
#       <td>0.088590</td>
#       <td>0.011305</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>0.001456</td>
#       <td>0.137521</td>
#       <td>0.025099</td>
#       <td>0.495564</td>
#       <td>0.001075</td>
#       <td>0.204051</td>
#       <td>0.115819</td>
#       <td>0.019414</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>0.001254</td>
#       <td>0.131096</td>
#       <td>0.022911</td>
#       <td>0.532615</td>
#       <td>0.001048</td>
#       <td>0.184651</td>
#       <td>0.108144</td>
#       <td>0.018281</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>0.001110</td>
#       <td>0.316343</td>
#       <td>0.058961</td>
#       <td>0.124513</td>
#       <td>0.000043</td>
#       <td>0.369347</td>
#       <td>0.095493</td>
#       <td>0.034190</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>0.000937</td>
#       <td>0.371114</td>
#       <td>0.046645</td>
#       <td>0.034786</td>
#       <td>0.000040</td>
#       <td>0.449162</td>
#       <td>0.072568</td>
#       <td>0.024747</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>0.000916</td>
#       <td>0.388575</td>
#       <td>0.043961</td>
#       <td>0.035553</td>
#       <td>0.000034</td>
#       <td>0.437526</td>
#       <td>0.067151</td>
#       <td>0.026285</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>0.000479</td>
#       <td>0.489969</td>
#       <td>0.065972</td>
#       <td>0.045532</td>
#       <td>0.000047</td>
#       <td>0.313843</td>
#       <td>0.053709</td>
#       <td>0.030450</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>0.000539</td>
#       <td>0.277402</td>
#       <td>0.019524</td>
#       <td>0.018600</td>
#       <td>0.000025</td>
#       <td>0.611744</td>
#       <td>0.047145</td>
#       <td>0.025020</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>0.000381</td>
#       <td>0.099613</td>
#       <td>0.004751</td>
#       <td>0.007303</td>
#       <td>0.000006</td>
#       <td>0.822644</td>
#       <td>0.027667</td>
#       <td>0.037635</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# Out:
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done   1 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done   2 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done   3 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done   4 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done   5 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done   6 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done   7 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done   8 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done   9 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done  10 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done  11 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done  12 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done  13 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done  14 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done  15 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done  16 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done  17 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done  18 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done  19 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done  20 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done  21 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done  22 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done  23 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done  24 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done  25 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=8)]: Done  26 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=8)]: Done  27 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=8)]: Done  28 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=8)]: Done  29 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=8)]: Done  30 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=8)]: Done  31 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=8)]: Done  32 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=8)]: Done  33 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=8)]: Done  35 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=8)]: Done  36 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=8)]: Done  37 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=8)]: Done  38 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=8)]: Done  39 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=8)]: Done  40 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=8)]: Done  41 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=8)]: Done  42 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=8)]: Done  43 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=8)]: Done  44 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=8)]: Done  45 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=8)]: Done  46 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=8)]: Done  47 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=8)]: Done  48 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=8)]: Done  49 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=8)]: Done  50 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=8)]: Done  51 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=8)]: Done  52 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=8)]: Done  53 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=8)]: Done  54 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=8)]: Done  55 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=8)]: Done  56 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done  57 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done  58 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done  59 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done  60 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done  61 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done  62 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=8)]: Done  63 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=8)]: Done  64 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=8)]: Done  65 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=8)]: Done  66 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=8)]: Done  67 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=8)]: Done  68 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=8)]: Done  69 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=8)]: Done  70 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=8)]: Done  71 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=8)]: Done  72 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=8)]: Done  73 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=8)]: Done  74 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=8)]: Done  75 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=8)]: Done  76 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=8)]: Done  77 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=8)]: Done  78 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=8)]: Done  79 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=8)]: Done  80 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=8)]: Done  81 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=8)]: Done  82 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=8)]: Done  83 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=8)]: Done  84 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=8)]: Done  85 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=8)]: Done  86 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=8)]: Done  87 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=8)]: Done  88 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=8)]: Done  89 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=8)]: Done  90 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=8)]: Done  91 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=8)]: Done  92 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=8)]: Done  93 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=8)]: Done  94 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=8)]: Done  95 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=8)]: Done  96 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=8)]: Done  97 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=8)]: Done  98 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=8)]: Done  99 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=8)]: Done 100 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=8)]: Done 101 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=8)]: Done 102 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=8)]: Done 103 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=8)]: Done 104 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=8)]: Done 105 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=8)]: Done 106 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=8)]: Done 107 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=8)]: Done 108 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=8)]: Done 109 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=8)]: Done 110 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=8)]: Done 111 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=8)]: Done 112 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=8)]: Done 113 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=8)]: Done 114 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=8)]: Done 115 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=8)]: Done 116 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=8)]: Done 117 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=8)]: Done 118 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=8)]: Done 119 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=8)]: Done 120 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=8)]: Done 121 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=8)]: Done 122 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=8)]: Done 123 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=8)]: Done 124 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=8)]: Done 125 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=8)]: Done 126 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=8)]: Done 127 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=8)]: Done 128 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=8)]: Done 129 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=8)]: Done 130 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=8)]: Done 131 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=8)]: Done 132 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=8)]: Done 133 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=8)]: Done 134 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=8)]: Done 135 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=8)]: Done 136 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=8)]: Done 137 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=8)]: Done 138 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=8)]: Done 139 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=8)]: Done 140 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=8)]: Done 141 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=8)]: Done 142 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=8)]: Done 143 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=8)]: Done 144 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=8)]: Done 145 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=8)]: Done 146 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=8)]: Done 147 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=8)]: Done 148 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=8)]: Done 149 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=8)]: Done 150 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=8)]: Done 151 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=8)]: Done 152 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=8)]: Done 153 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=8)]: Done 154 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=8)]: Done 155 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=8)]: Done 156 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=8)]: Done 157 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=8)]: Done 158 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=8)]: Done 159 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=8)]: Done 160 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=8)]: Done 161 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=8)]: Done 162 tasks      | elapsed:    3.2s
# [Parallel(n_jobs=8)]: Done 163 tasks      | elapsed:    3.2s
# [Parallel(n_jobs=8)]: Done 164 tasks      | elapsed:    3.2s
# [Parallel(n_jobs=8)]: Done 165 tasks      | elapsed:    3.2s
# [Parallel(n_jobs=8)]: Done 166 tasks      | elapsed:    3.2s
# [Parallel(n_jobs=8)]: Done 167 tasks      | elapsed:    3.2s
# [Parallel(n_jobs=8)]: Done 168 tasks      | elapsed:    3.3s
# [Parallel(n_jobs=8)]: Done 169 tasks      | elapsed:    3.3s
# [Parallel(n_jobs=8)]: Done 170 tasks      | elapsed:    3.3s
# [Parallel(n_jobs=8)]: Done 171 tasks      | elapsed:    3.3s
# [Parallel(n_jobs=8)]: Done 172 tasks      | elapsed:    3.3s
# [Parallel(n_jobs=8)]: Done 173 tasks      | elapsed:    3.3s
# [Parallel(n_jobs=8)]: Done 174 tasks      | elapsed:    3.4s
# [Parallel(n_jobs=8)]: Done 175 tasks      | elapsed:    3.4s
# [Parallel(n_jobs=8)]: Done 176 tasks      | elapsed:    3.4s
# [Parallel(n_jobs=8)]: Done 177 tasks      | elapsed:    3.4s
# [Parallel(n_jobs=8)]: Done 178 tasks      | elapsed:    3.5s
# [Parallel(n_jobs=8)]: Done 179 tasks      | elapsed:    3.5s
# [Parallel(n_jobs=8)]: Done 180 tasks      | elapsed:    3.5s
# [Parallel(n_jobs=8)]: Done 181 tasks      | elapsed:    3.5s
# [Parallel(n_jobs=8)]: Done 182 tasks      | elapsed:    3.5s
# [Parallel(n_jobs=8)]: Done 183 tasks      | elapsed:    3.5s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    3.6s
# [Parallel(n_jobs=8)]: Done 185 tasks      | elapsed:    3.6s
# [Parallel(n_jobs=8)]: Done 186 tasks      | elapsed:    3.7s
# [Parallel(n_jobs=8)]: Done 187 tasks      | elapsed:    3.7s
# [Parallel(n_jobs=8)]: Done 188 tasks      | elapsed:    3.7s
# [Parallel(n_jobs=8)]: Done 189 tasks      | elapsed:    3.7s
# [Parallel(n_jobs=8)]: Done 190 tasks      | elapsed:    3.7s
# [Parallel(n_jobs=8)]: Done 191 tasks      | elapsed:    3.7s
# [Parallel(n_jobs=8)]: Done 192 tasks      | elapsed:    3.8s
# [Parallel(n_jobs=8)]: Done 193 tasks      | elapsed:    3.8s
# [Parallel(n_jobs=8)]: Done 194 tasks      | elapsed:    3.8s
# [Parallel(n_jobs=8)]: Done 195 tasks      | elapsed:    3.8s
# [Parallel(n_jobs=8)]: Done 196 tasks      | elapsed:    3.8s
# [Parallel(n_jobs=8)]: Done 197 tasks      | elapsed:    3.8s
# [Parallel(n_jobs=8)]: Done 198 tasks      | elapsed:    3.9s
# [Parallel(n_jobs=8)]: Done 199 tasks      | elapsed:    3.9s
# [Parallel(n_jobs=8)]: Done 200 tasks      | elapsed:    3.9s
# [Parallel(n_jobs=8)]: Done 201 tasks      | elapsed:    4.0s
# [Parallel(n_jobs=8)]: Done 202 tasks      | elapsed:    4.0s
# [Parallel(n_jobs=8)]: Done 203 tasks      | elapsed:    4.0s
# [Parallel(n_jobs=8)]: Done 204 tasks      | elapsed:    4.0s
# [Parallel(n_jobs=8)]: Done 205 tasks      | elapsed:    4.0s
# [Parallel(n_jobs=8)]: Done 206 tasks      | elapsed:    4.0s
# [Parallel(n_jobs=8)]: Done 207 tasks      | elapsed:    4.0s
# [Parallel(n_jobs=8)]: Done 208 tasks      | elapsed:    4.1s
# [Parallel(n_jobs=8)]: Done 209 tasks      | elapsed:    4.1s
# [Parallel(n_jobs=8)]: Done 210 tasks      | elapsed:    4.1s
# [Parallel(n_jobs=8)]: Done 211 tasks      | elapsed:    4.1s
# [Parallel(n_jobs=8)]: Done 212 tasks      | elapsed:    4.2s
# [Parallel(n_jobs=8)]: Done 213 tasks      | elapsed:    4.2s
# [Parallel(n_jobs=8)]: Done 214 tasks      | elapsed:    4.2s
# [Parallel(n_jobs=8)]: Done 215 tasks      | elapsed:    4.2s
# [Parallel(n_jobs=8)]: Done 216 tasks      | elapsed:    4.2s
# [Parallel(n_jobs=8)]: Done 217 tasks      | elapsed:    4.3s
# [Parallel(n_jobs=8)]: Done 218 tasks      | elapsed:    4.3s
# [Parallel(n_jobs=8)]: Done 219 tasks      | elapsed:    4.3s
# [Parallel(n_jobs=8)]: Done 220 tasks      | elapsed:    4.3s
# [Parallel(n_jobs=8)]: Done 221 tasks      | elapsed:    4.3s
# [Parallel(n_jobs=8)]: Done 222 tasks      | elapsed:    4.3s
# [Parallel(n_jobs=8)]: Done 223 tasks      | elapsed:    4.3s
# [Parallel(n_jobs=8)]: Done 224 tasks      | elapsed:    4.4s
# [Parallel(n_jobs=8)]: Done 225 tasks      | elapsed:    4.4s
# [Parallel(n_jobs=8)]: Done 226 tasks      | elapsed:    4.4s
# [Parallel(n_jobs=8)]: Done 227 tasks      | elapsed:    4.4s
# [Parallel(n_jobs=8)]: Done 228 tasks      | elapsed:    4.5s
# [Parallel(n_jobs=8)]: Done 229 tasks      | elapsed:    4.5s
# [Parallel(n_jobs=8)]: Done 230 tasks      | elapsed:    4.5s
# [Parallel(n_jobs=8)]: Done 231 tasks      | elapsed:    4.5s
# [Parallel(n_jobs=8)]: Done 232 tasks      | elapsed:    4.5s
# [Parallel(n_jobs=8)]: Done 233 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=8)]: Done 234 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=8)]: Done 235 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=8)]: Done 236 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=8)]: Done 237 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=8)]: Done 238 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=8)]: Done 239 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=8)]: Done 240 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=8)]: Done 241 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=8)]: Done 242 tasks      | elapsed:    4.8s
# [Parallel(n_jobs=8)]: Done 243 tasks      | elapsed:    4.8s
# [Parallel(n_jobs=8)]: Done 244 tasks      | elapsed:    4.8s
# [Parallel(n_jobs=8)]: Done 245 tasks      | elapsed:    4.8s
# [Parallel(n_jobs=8)]: Done 246 tasks      | elapsed:    4.8s
# [Parallel(n_jobs=8)]: Done 247 tasks      | elapsed:    4.9s
# [Parallel(n_jobs=8)]: Done 248 tasks      | elapsed:    4.9s
# [Parallel(n_jobs=8)]: Done 249 tasks      | elapsed:    4.9s
# [Parallel(n_jobs=8)]: Done 250 tasks      | elapsed:    4.9s
# [Parallel(n_jobs=8)]: Done 251 tasks      | elapsed:    4.9s
# [Parallel(n_jobs=8)]: Done 252 tasks      | elapsed:    4.9s
# [Parallel(n_jobs=8)]: Done 253 tasks      | elapsed:    4.9s
# [Parallel(n_jobs=8)]: Done 254 tasks      | elapsed:    5.0s
# [Parallel(n_jobs=8)]: Done 255 tasks      | elapsed:    5.0s
# [Parallel(n_jobs=8)]: Done 256 tasks      | elapsed:    5.0s
# [Parallel(n_jobs=8)]: Done 257 tasks      | elapsed:    5.1s
# [Parallel(n_jobs=8)]: Done 258 tasks      | elapsed:    5.1s
# [Parallel(n_jobs=8)]: Done 259 tasks      | elapsed:    5.1s
# [Parallel(n_jobs=8)]: Done 260 tasks      | elapsed:    5.1s
# [Parallel(n_jobs=8)]: Done 261 tasks      | elapsed:    5.1s
# [Parallel(n_jobs=8)]: Done 262 tasks      | elapsed:    5.1s
# [Parallel(n_jobs=8)]: Done 263 tasks      | elapsed:    5.2s
# [Parallel(n_jobs=8)]: Done 264 tasks      | elapsed:    5.2s
# [Parallel(n_jobs=8)]: Done 265 tasks      | elapsed:    5.2s
# [Parallel(n_jobs=8)]: Done 266 tasks      | elapsed:    5.2s
# [Parallel(n_jobs=8)]: Done 267 tasks      | elapsed:    5.3s
# [Parallel(n_jobs=8)]: Done 268 tasks      | elapsed:    5.3s
# [Parallel(n_jobs=8)]: Done 269 tasks      | elapsed:    5.3s
# [Parallel(n_jobs=8)]: Done 270 tasks      | elapsed:    5.3s
# [Parallel(n_jobs=8)]: Done 271 tasks      | elapsed:    5.3s
# [Parallel(n_jobs=8)]: Done 272 tasks      | elapsed:    5.3s
# [Parallel(n_jobs=8)]: Done 273 tasks      | elapsed:    5.3s
# [Parallel(n_jobs=8)]: Done 274 tasks      | elapsed:    5.4s
# [Parallel(n_jobs=8)]: Done 275 tasks      | elapsed:    5.4s
# [Parallel(n_jobs=8)]: Done 276 tasks      | elapsed:    5.4s
# [Parallel(n_jobs=8)]: Done 277 tasks      | elapsed:    5.4s
# [Parallel(n_jobs=8)]: Done 278 tasks      | elapsed:    5.4s
# [Parallel(n_jobs=8)]: Done 279 tasks      | elapsed:    5.5s
# [Parallel(n_jobs=8)]: Done 280 tasks      | elapsed:    5.5s
# [Parallel(n_jobs=8)]: Done 281 tasks      | elapsed:    5.5s
# [Parallel(n_jobs=8)]: Done 282 tasks      | elapsed:    5.5s
# [Parallel(n_jobs=8)]: Done 283 tasks      | elapsed:    5.5s
# [Parallel(n_jobs=8)]: Done 284 tasks      | elapsed:    5.6s
# [Parallel(n_jobs=8)]: Done 285 tasks      | elapsed:    5.6s
# [Parallel(n_jobs=8)]: Done 286 tasks      | elapsed:    5.6s
# [Parallel(n_jobs=8)]: Done 287 tasks      | elapsed:    5.6s
# [Parallel(n_jobs=8)]: Done 288 tasks      | elapsed:    5.6s
# [Parallel(n_jobs=8)]: Done 289 tasks      | elapsed:    5.6s
# [Parallel(n_jobs=8)]: Done 290 tasks      | elapsed:    5.7s
# [Parallel(n_jobs=8)]: Done 291 tasks      | elapsed:    5.7s
# [Parallel(n_jobs=8)]: Done 292 tasks      | elapsed:    5.7s
# [Parallel(n_jobs=8)]: Done 293 tasks      | elapsed:    5.8s
# [Parallel(n_jobs=8)]: Done 294 tasks      | elapsed:    5.8s
# [Parallel(n_jobs=8)]: Done 295 tasks      | elapsed:    5.8s
# [Parallel(n_jobs=8)]: Done 296 tasks      | elapsed:    5.8s
# [Parallel(n_jobs=8)]: Done 297 tasks      | elapsed:    5.9s
# [Parallel(n_jobs=8)]: Done 298 tasks      | elapsed:    5.9s
# [Parallel(n_jobs=8)]: Done 299 tasks      | elapsed:    5.9s
# [Parallel(n_jobs=8)]: Done 300 tasks      | elapsed:    5.9s
# [Parallel(n_jobs=8)]: Done 301 tasks      | elapsed:    5.9s
# [Parallel(n_jobs=8)]: Done 302 tasks      | elapsed:    6.0s
# [Parallel(n_jobs=8)]: Done 303 tasks      | elapsed:    6.0s
# [Parallel(n_jobs=8)]: Done 304 tasks      | elapsed:    6.0s
# [Parallel(n_jobs=8)]: Done 305 tasks      | elapsed:    6.0s
# [Parallel(n_jobs=8)]: Done 306 tasks      | elapsed:    6.0s
# [Parallel(n_jobs=8)]: Done 307 tasks      | elapsed:    6.0s
# [Parallel(n_jobs=8)]: Done 308 tasks      | elapsed:    6.0s
# [Parallel(n_jobs=8)]: Done 309 tasks      | elapsed:    6.1s
# [Parallel(n_jobs=8)]: Done 310 tasks      | elapsed:    6.1s
# [Parallel(n_jobs=8)]: Done 311 tasks      | elapsed:    6.1s
# [Parallel(n_jobs=8)]: Done 312 tasks      | elapsed:    6.1s
# [Parallel(n_jobs=8)]: Done 313 tasks      | elapsed:    6.1s
# [Parallel(n_jobs=8)]: Done 314 tasks      | elapsed:    6.1s
# [Parallel(n_jobs=8)]: Done 315 tasks      | elapsed:    6.2s
# [Parallel(n_jobs=8)]: Done 316 tasks      | elapsed:    6.2s
# [Parallel(n_jobs=8)]: Done 317 tasks      | elapsed:    6.3s
# [Parallel(n_jobs=8)]: Done 318 tasks      | elapsed:    6.3s
# [Parallel(n_jobs=8)]: Done 319 tasks      | elapsed:    6.3s
# [Parallel(n_jobs=8)]: Done 320 tasks      | elapsed:    6.3s
# [Parallel(n_jobs=8)]: Done 321 tasks      | elapsed:    6.3s
# [Parallel(n_jobs=8)]: Done 322 tasks      | elapsed:    6.3s
# [Parallel(n_jobs=8)]: Done 323 tasks      | elapsed:    6.3s
# [Parallel(n_jobs=8)]: Done 324 tasks      | elapsed:    6.4s
# [Parallel(n_jobs=8)]: Done 325 tasks      | elapsed:    6.4s
# [Parallel(n_jobs=8)]: Done 326 tasks      | elapsed:    6.4s
# [Parallel(n_jobs=8)]: Done 327 tasks      | elapsed:    6.4s
# [Parallel(n_jobs=8)]: Done 328 tasks      | elapsed:    6.5s
# [Parallel(n_jobs=8)]: Done 329 tasks      | elapsed:    6.5s
# [Parallel(n_jobs=8)]: Done 330 tasks      | elapsed:    6.5s
# [Parallel(n_jobs=8)]: Done 331 tasks      | elapsed:    6.5s
# [Parallel(n_jobs=8)]: Done 332 tasks      | elapsed:    6.5s
# [Parallel(n_jobs=8)]: Done 333 tasks      | elapsed:    6.5s
# [Parallel(n_jobs=8)]: Done 334 tasks      | elapsed:    6.6s
# [Parallel(n_jobs=8)]: Done 335 tasks      | elapsed:    6.6s
# [Parallel(n_jobs=8)]: Done 336 tasks      | elapsed:    6.6s
# [Parallel(n_jobs=8)]: Done 337 tasks      | elapsed:    6.6s
# [Parallel(n_jobs=8)]: Done 338 tasks      | elapsed:    6.6s
# [Parallel(n_jobs=8)]: Done 339 tasks      | elapsed:    6.6s
# [Parallel(n_jobs=8)]: Done 340 tasks      | elapsed:    6.7s
# [Parallel(n_jobs=8)]: Done 341 tasks      | elapsed:    6.7s
# [Parallel(n_jobs=8)]: Done 342 tasks      | elapsed:    6.7s
# [Parallel(n_jobs=8)]: Done 343 tasks      | elapsed:    6.7s
# [Parallel(n_jobs=8)]: Done 344 tasks      | elapsed:    6.7s
# [Parallel(n_jobs=8)]: Done 345 tasks      | elapsed:    6.8s
# [Parallel(n_jobs=8)]: Done 346 tasks      | elapsed:    6.8s
# [Parallel(n_jobs=8)]: Done 347 tasks      | elapsed:    6.8s
# [Parallel(n_jobs=8)]: Done 348 tasks      | elapsed:    6.8s
# [Parallel(n_jobs=8)]: Done 349 tasks      | elapsed:    6.8s
# [Parallel(n_jobs=8)]: Done 350 tasks      | elapsed:    6.8s
# [Parallel(n_jobs=8)]: Done 351 tasks      | elapsed:    6.9s
# [Parallel(n_jobs=8)]: Done 352 tasks      | elapsed:    6.9s
# [Parallel(n_jobs=8)]: Done 353 tasks      | elapsed:    6.9s
# [Parallel(n_jobs=8)]: Done 354 tasks      | elapsed:    6.9s
# [Parallel(n_jobs=8)]: Done 355 tasks      | elapsed:    6.9s
# [Parallel(n_jobs=8)]: Done 356 tasks      | elapsed:    6.9s
# [Parallel(n_jobs=8)]: Done 357 tasks      | elapsed:    7.0s
# [Parallel(n_jobs=8)]: Done 358 tasks      | elapsed:    7.0s
# [Parallel(n_jobs=8)]: Done 359 tasks      | elapsed:    7.0s
# [Parallel(n_jobs=8)]: Done 360 tasks      | elapsed:    7.0s
# [Parallel(n_jobs=8)]: Done 361 tasks      | elapsed:    7.0s
# [Parallel(n_jobs=8)]: Done 362 tasks      | elapsed:    7.0s
# [Parallel(n_jobs=8)]: Done 363 tasks      | elapsed:    7.1s
# [Parallel(n_jobs=8)]: Done 364 tasks      | elapsed:    7.1s
# [Parallel(n_jobs=8)]: Done 365 tasks      | elapsed:    7.1s
# [Parallel(n_jobs=8)]: Done 366 tasks      | elapsed:    7.1s
# [Parallel(n_jobs=8)]: Done 367 tasks      | elapsed:    7.1s
# [Parallel(n_jobs=8)]: Done 368 tasks      | elapsed:    7.2s
# [Parallel(n_jobs=8)]: Done 369 tasks      | elapsed:    7.2s
# [Parallel(n_jobs=8)]: Done 370 tasks      | elapsed:    7.2s
# [Parallel(n_jobs=8)]: Done 371 tasks      | elapsed:    7.2s
# [Parallel(n_jobs=8)]: Done 372 tasks      | elapsed:    7.2s
# [Parallel(n_jobs=8)]: Done 373 tasks      | elapsed:    7.2s
# [Parallel(n_jobs=8)]: Done 374 tasks      | elapsed:    7.2s
# [Parallel(n_jobs=8)]: Done 375 tasks      | elapsed:    7.3s
# [Parallel(n_jobs=8)]: Done 376 tasks      | elapsed:    7.3s
# [Parallel(n_jobs=8)]: Done 377 tasks      | elapsed:    7.3s
# [Parallel(n_jobs=8)]: Done 378 tasks      | elapsed:    7.3s
# [Parallel(n_jobs=8)]: Done 379 tasks      | elapsed:    7.3s
# [Parallel(n_jobs=8)]: Done 380 tasks      | elapsed:    7.4s
# [Parallel(n_jobs=8)]: Done 381 tasks      | elapsed:    7.4s
# [Parallel(n_jobs=8)]: Done 382 tasks      | elapsed:    7.4s
# [Parallel(n_jobs=8)]: Done 383 tasks      | elapsed:    7.4s
# [Parallel(n_jobs=8)]: Done 384 tasks      | elapsed:    7.4s
# [Parallel(n_jobs=8)]: Done 385 tasks      | elapsed:    7.4s
# [Parallel(n_jobs=8)]: Done 386 tasks      | elapsed:    7.5s
# [Parallel(n_jobs=8)]: Done 387 tasks      | elapsed:    7.5s
# [Parallel(n_jobs=8)]: Done 388 tasks      | elapsed:    7.5s
# [Parallel(n_jobs=8)]: Done 389 tasks      | elapsed:    7.5s
# [Parallel(n_jobs=8)]: Done 390 tasks      | elapsed:    7.5s
# [Parallel(n_jobs=8)]: Done 391 tasks      | elapsed:    7.6s
# [Parallel(n_jobs=8)]: Done 392 tasks      | elapsed:    7.6s
# [Parallel(n_jobs=8)]: Done 393 tasks      | elapsed:    7.6s
# [Parallel(n_jobs=8)]: Done 394 tasks      | elapsed:    7.6s
# [Parallel(n_jobs=8)]: Done 395 tasks      | elapsed:    7.6s
# [Parallel(n_jobs=8)]: Done 396 tasks      | elapsed:    7.6s
# [Parallel(n_jobs=8)]: Done 397 tasks      | elapsed:    7.7s
# [Parallel(n_jobs=8)]: Done 398 tasks      | elapsed:    7.7s
# [Parallel(n_jobs=8)]: Done 399 tasks      | elapsed:    7.7s
# [Parallel(n_jobs=8)]: Done 400 tasks      | elapsed:    7.7s
# [Parallel(n_jobs=8)]: Done 401 tasks      | elapsed:    7.7s
# [Parallel(n_jobs=8)]: Done 402 tasks      | elapsed:    7.8s
# [Parallel(n_jobs=8)]: Done 403 tasks      | elapsed:    7.8s
# [Parallel(n_jobs=8)]: Done 404 tasks      | elapsed:    7.8s
# [Parallel(n_jobs=8)]: Done 405 tasks      | elapsed:    7.8s
# [Parallel(n_jobs=8)]: Done 406 tasks      | elapsed:    7.8s
# [Parallel(n_jobs=8)]: Done 407 tasks      | elapsed:    7.8s
# [Parallel(n_jobs=8)]: Done 408 tasks      | elapsed:    7.8s
# [Parallel(n_jobs=8)]: Done 409 tasks      | elapsed:    7.9s
# [Parallel(n_jobs=8)]: Done 410 tasks      | elapsed:    7.9s
# [Parallel(n_jobs=8)]: Done 411 tasks      | elapsed:    7.9s
# [Parallel(n_jobs=8)]: Done 412 tasks      | elapsed:    7.9s
# [Parallel(n_jobs=8)]: Done 413 tasks      | elapsed:    7.9s
# [Parallel(n_jobs=8)]: Done 414 tasks      | elapsed:    8.0s
# [Parallel(n_jobs=8)]: Done 415 tasks      | elapsed:    8.0s
# [Parallel(n_jobs=8)]: Done 416 tasks      | elapsed:    8.0s
# [Parallel(n_jobs=8)]: Done 417 tasks      | elapsed:    8.0s
# [Parallel(n_jobs=8)]: Done 418 tasks      | elapsed:    8.0s
# [Parallel(n_jobs=8)]: Done 419 tasks      | elapsed:    8.1s
# [Parallel(n_jobs=8)]: Done 420 tasks      | elapsed:    8.1s
# [Parallel(n_jobs=8)]: Done 421 tasks      | elapsed:    8.1s
# [Parallel(n_jobs=8)]: Done 422 tasks      | elapsed:    8.1s
# [Parallel(n_jobs=8)]: Done 423 tasks      | elapsed:    8.1s
# [Parallel(n_jobs=8)]: Done 424 tasks      | elapsed:    8.1s
# [Parallel(n_jobs=8)]: Done 425 tasks      | elapsed:    8.2s
# [Parallel(n_jobs=8)]: Done 426 tasks      | elapsed:    8.2s
# [Parallel(n_jobs=8)]: Done 427 tasks      | elapsed:    8.2s
# [Parallel(n_jobs=8)]: Done 428 tasks      | elapsed:    8.2s
# [Parallel(n_jobs=8)]: Done 429 tasks      | elapsed:    8.2s
# [Parallel(n_jobs=8)]: Done 430 tasks      | elapsed:    8.3s
# [Parallel(n_jobs=8)]: Done 431 tasks      | elapsed:    8.3s
# [Parallel(n_jobs=8)]: Done 432 tasks      | elapsed:    8.3s
# [Parallel(n_jobs=8)]: Done 433 tasks      | elapsed:    8.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    8.4s
# [Parallel(n_jobs=8)]: Done 435 tasks      | elapsed:    8.4s
# [Parallel(n_jobs=8)]: Done 440 out of 450 | elapsed:    8.5s remaining:    0.2s
# [Parallel(n_jobs=8)]: Done 445 out of 450 | elapsed:    8.6s remaining:    0.1s
# [Parallel(n_jobs=8)]: Done 450 out of 450 | elapsed:    8.7s remaining:    0.0s
# [Parallel(n_jobs=8)]: Done 450 out of 450 | elapsed:    8.7s finished
#                0         1         2         3         4         5         6  \
# 2       0.001627  0.116460  0.022646  0.543364  0.003435  0.175361  0.120722
# 3       0.001256  0.110399  0.020726  0.578062  0.002997  0.159085  0.111848
# 4       0.000609  0.071220  0.012759  0.711120  0.003036  0.101360  0.088590
# 5       0.001456  0.137521  0.025099  0.495564  0.001075  0.204051  0.115819
# 6       0.001254  0.131096  0.022911  0.532615  0.001048  0.184651  0.108144
# ...          ...       ...       ...       ...       ...       ...       ...
# 816791  0.168233  0.204186  0.066057  0.128731  0.001002  0.150655  0.158923
# 816792  0.135444  0.234633  0.081416  0.109536  0.000922  0.150072  0.164832
# 816793  0.139286  0.186490  0.084554  0.133448  0.000871  0.135476  0.158940
# 816795  0.117405  0.121576  0.048240  0.034639  0.001163  0.103678  0.152964
# 816796  0.518621  0.162535  0.060452  0.059996  0.000770  0.058404  0.094020
#
#                7
# 2       0.016386
# 3       0.015627
# 4       0.011305
# 5       0.019414
# 6       0.018281
# ...          ...
# 816791  0.122212
# 816792  0.123145
# 816793  0.160935
# 816795  0.420333
# 816796  0.045202
#
# [523077 rows x 8 columns]
